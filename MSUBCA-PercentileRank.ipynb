# %%
conda list
# Out:
# # packages in environment at C:\Users\iamvr\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# absl-py                   0.9.0                    pypi_0    pypi
# alabaster                 0.7.12                   py37_0
# anaconda                  2019.03                  py37_0
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.7                    py37_0
# anaconda-project          0.8.2                    py37_0
# asn1crypto                0.24.0                   py37_0
# astor                     0.8.1                    pypi_0    pypi
# astroid                   2.2.5                    py37_0
# astropy                   3.1.2            py37he774522_0
# atomicwrites              1.3.0                    py37_1
# attrs                     19.1.0                   py37_1
# babel                     2.6.0                    py37_0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data = pd.read_csv(r'C:\Users\iamvr\Desktop\file.csv')

# %%
data
# Out:
#                                        Name   Sem5  Rank  Percent
# 0               Mishra Anshika Pavan Mishra  94.07     1  100.00%
# 1                     Goswami Jayati Sharad  87.41     2   98.70%
# 2                      Shah Yash Samitkumar  81.48     3   97.50%
# 3                     Syed Samar Sharfuddin  80.83     4   96.20%
# 4                        Batas Riddhi Raman  78.52     5   95.00%
# 5                          Patel Ami Bharat  77.04     6   93.70%
# 6                       Kapadia Abha Kishor  76.67     7   92.50%
# 7                        Vyas Bhumi Prakash  74.81     8   91.20%
# 8                 Baseta Vandana Satishbhai  74.17     9   88.70%
# 9                        Khatri Amit Suresh  74.17     9   88.70%
# 10         Psn R S S Vamsy Bala Subramanyam  72.50    11   87.50%
# 11                      Kotwala Vraj Rajesh  71.85    12   86.20%
# 12                  Nanda Kamakshi Devinder  71.11    13   83.70%
# ...

# %%
data.describe()
# Out:
#             Sem5       Rank
# count  81.000000  81.000000
# mean   54.417284  40.691358
# std    16.459174  23.447090
# min    15.000000   1.000000
# 25%    43.700000  21.000000
# 50%    54.170000  40.000000
# 75%    66.670000  61.000000
# max    94.070000  81.000000

# %%
data['Percentile_rank']=data.Sem5.rank(pct=True)
print(data)
# Out:
#                                        Name   Sem5  Rank  Percent  \
# 0               Mishra Anshika Pavan Mishra  94.07     1  100.00%
# 1                     Goswami Jayati Sharad  87.41     2   98.70%
# 2                      Shah Yash Samitkumar  81.48     3   97.50%
# 3                     Syed Samar Sharfuddin  80.83     4   96.20%
# 4                        Batas Riddhi Raman  78.52     5   95.00%
# 5                          Patel Ami Bharat  77.04     6   93.70%
# 6                       Kapadia Abha Kishor  76.67     7   92.50%
# 7                        Vyas Bhumi Prakash  74.81     8   91.20%
# 8                 Baseta Vandana Satishbhai  74.17     9   88.70%
# 9                        Khatri Amit Suresh  74.17     9   88.70%
# 10         Psn R S S Vamsy Bala Subramanyam  72.50    11   87.50%
# 11                      Kotwala Vraj Rajesh  71.85    12   86.20%
# 12                  Nanda Kamakshi Devinder  71.11    13   83.70%
# ...

# %%
#y = b0 + b1(x1)
y = data['Sem5']
x1 = data['Percent']

# %%
plt.scatter(x1,y)
plt.xlabel('Percentile', fontsize=20)
plt.ylabel('Sem5', fontsize=20)
plt.show()
